# %%
from automata import *

# %%
CellularAutomata(30, [-5], frame_steps=12, frame_width=15, boundary_condition='periodic').display(
    check_highlight_bounds=True, 
    highlights=[HighlightBounds(width=5, steps=7, start_step=4, offset=-6)],
    grid_color='red', grid_width=1.0)
# Out:
# ---------------------------------------------------------------------------
# CellularAutomataError                     Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 CellularAutomata(30, [-5], frame_steps=12, frame_width=15, boundary_condition='periodic').display(
#       2     check_highlight_bounds=True,
#       3     highlights=[HighlightBounds(width=5, steps=7, start_step=4, offset=-6)],
#       4     grid_color='red', grid_width=1.0)
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:177, in CellularAutomata.display(self, *args, **kwargs)
#     176 def display(self, *args, **kwargs):
# --> 177     _, _ = self.get_display(*args, **kwargs)
#     178     plt.show()
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:134, in CellularAutomata.get_display(self, fig_width, highlights, highlight_mask, grid_color, grid_width, cell_colors, check_highlight_bounds)
#     132     error_messages = self._check_highlight_bounds(highlight)
# ...

# %%
CellularAutomata(30, [-5], frame_steps=12, frame_width=15, boundary_condition='periodic').display(
    check_highlight_bounds=False, 
    highlights=[HighlightBounds(width=5, steps=7, start_step=4, offset=-6)],
    grid_color='red', grid_width=1.0)

# %%
CellularAutomata(30, [-5], frame_steps=12, frame_width=15, boundary_condition='periodic').display(
    check_highlight_bounds=True, 
    highlights=[HighlightBounds(steps=5, start_step=0, offset=-6, width=5)],
    #highlight_width=5, highlight_steps=5, highlight_start_step=0, highlight_offset=-6, 
    grid_color='red', grid_width=1.0)
# Out:
# ---------------------------------------------------------------------------
# CellularAutomataError                     Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 CellularAutomata(30, [-5], frame_steps=12, frame_width=15, boundary_condition='periodic').display(
#       2     check_highlight_bounds=True,
#       3     highlights=[HighlightBounds(steps=5, start_step=0, offset=-6, width=5)],
#       4     #highlight_width=5, highlight_steps=5, highlight_start_step=0, highlight_offset=-6,
#       5     grid_color='red', grid_width=1.0)
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:177, in CellularAutomata.display(self, *args, **kwargs)
#     176 def display(self, *args, **kwargs):
# --> 177     _, _ = self.get_display(*args, **kwargs)
#     178     plt.show()
#
# ...

# %%
CellularAutomata(30, [-5], frame_steps=12, frame_width=15, boundary_condition='periodic').display(
    fig_width=8, check_highlight_bounds=False, 
    highlights=[HighlightBounds(steps=5, start_step=0, offset=-6, width=5)],
    # highlight_width=5, highlight_steps=5, highlight_start_step=0, highlight_offset=-6, 
    grid_color='red', grid_width=1.0)

# %%
CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
    check_highlight_bounds=True, 
    highlights=[HighlightBounds(steps=5, start_step=10, offset=-5, width=5)])
# Out:
# ---------------------------------------------------------------------------
# CellularAutomataError                     Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
#       2     check_highlight_bounds=True,
#       3     highlights=[HighlightBounds(steps=5, start_step=10, offset=-5, width=5)])
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:177, in CellularAutomata.display(self, *args, **kwargs)
#     176 def display(self, *args, **kwargs):
# --> 177     _, _ = self.get_display(*args, **kwargs)
#     178     plt.show()
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:134, in CellularAutomata.get_display(self, fig_width, highlights, highlight_mask, grid_color, grid_width, cell_colors, check_highlight_bounds)
#     132     error_messages = self._check_highlight_bounds(highlight)
#     133     if error_messages:
# ...

# %%
CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
    check_highlight_bounds=False, 
    highlights=[HighlightBounds(steps=5, start_step=10, offset=-5, width=5)])
    # highlight_width=5, highlight_steps=5, highlight_start_step=10, highlight_offset=-5)

# %%
CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
    check_highlight_bounds=True, 
    highlights=[HighlightBounds(steps=5, start_step=-2, offset=0, width=5)])
# Out:
# ---------------------------------------------------------------------------
# CellularAutomataError                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
#       2     check_highlight_bounds=True,
#       3     highlights=[HighlightBounds(steps=5, start_step=-2, offset=0, width=5)])
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:177, in CellularAutomata.display(self, *args, **kwargs)
#     176 def display(self, *args, **kwargs):
# --> 177     _, _ = self.get_display(*args, **kwargs)
#     178     plt.show()
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:134, in CellularAutomata.get_display(self, fig_width, highlights, highlight_mask, grid_color, grid_width, cell_colors, check_highlight_bounds)
#     132     error_messages = self._check_highlight_bounds(highlight)
#     133     if error_messages:
# ...

# %%
CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
    check_highlight_bounds=False, 
    highlights=[HighlightBounds(steps=5, start_step=-2, offset=0, width=5)])

# %%
CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
    check_highlight_bounds=True, 
    highlights=[HighlightBounds(steps=5, start_step=10, offset=0, width=5)])
# Out:
# ---------------------------------------------------------------------------
# CellularAutomataError                     Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
#       2     check_highlight_bounds=True,
#       3     highlights=[HighlightBounds(steps=5, start_step=10, offset=0, width=5)])
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:177, in CellularAutomata.display(self, *args, **kwargs)
#     176 def display(self, *args, **kwargs):
# --> 177     _, _ = self.get_display(*args, **kwargs)
#     178     plt.show()
#
# File ~/Documents/Projects/Coding/Python/automata/automata.py:134, in CellularAutomata.get_display(self, fig_width, highlights, highlight_mask, grid_color, grid_width, cell_colors, check_highlight_bounds)
#     132     error_messages = self._check_highlight_bounds(highlight)
#     133     if error_messages:
# ...

# %%
CellularAutomata(30, [0], frame_steps=12, frame_width=15).display(
    check_highlight_bounds=False, 
    highlights=[HighlightBounds(steps=5, start_step=10, offset=0, width=5)])
